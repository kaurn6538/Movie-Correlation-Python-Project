# %%
#import liberaries
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r'/Users/sonunancy/Desktop/movies.csv')

# %%
# lets look into the data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000.0
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000.0
# 2           Leigh Brackett     Mark Hamill   United States  18000000.0
# 3             Jim Abrahams     Robert Hays   United States   3500000.0
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000.0
#
#          gross             company  runtime
# 0   46998772.0        Warner Bros.    146.0
# 1   58853106.0   Columbia Pictures    104.0
# 2  538375067.0           Lucasfilm    124.0
# 3   83453539.0  Paramount Pictures     88.0
# 4   39846344.0      Orion Pictures     98.0

# %%
df.columns
# Out:
# Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')

# %%
# Let's see if there is some missing data
for col in df.columns:
    pct_missing=np.mean(df[col].isnull())
    print('{} - {}%'.format(col,pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
# Data Types for our columns
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
#change data type of columnsa
df['budget']=pd.to_numeric(df['budget'],errors='coerce').fillna(0).astype(int)
df['budget']= df['budget'].astype('int')

df['gross']=pd.to_numeric(df['gross'],errors='coerce').fillna(0).astype(int)
df['gross']= df['gross'].astype('int')

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime
# 0   46998772        Warner Bros.    146.0
# 1   58853106   Columbia Pictures    104.0
# 2  538375067           Lucasfilm    124.0
# 3   83453539  Paramount Pictures     88.0
# 4   39846344      Orion Pictures     98.0

# %%
#create correct year column
df['year_correct'] = pd.to_datetime(df['released'].str.extract(r'(\w+ \d+, \d+)', expand=False), format = '%B %d, %Y')
df['year']=df['year_correct'].astype(str).str[:4]

df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country    budget  \
# 0             Stephen King  Jack Nicholson  United Kingdom  19000000
# 1  Henry De Vere Stacpoole  Brooke Shields   United States   4500000
# 2           Leigh Brackett     Mark Hamill   United States  18000000
# 3             Jim Abrahams     Robert Hays   United States   3500000
# 4       Brian Doyle-Murray     Chevy Chase   United States   6000000
#
#        gross             company  runtime year_correct
# 0   46998772        Warner Bros.    146.0   1980-06-13
# 1   58853106   Columbia Pictures    104.0   1980-07-02
# 2  538375067           Lucasfilm    124.0   1980-06-20
# 3   83453539  Paramount Pictures     88.0   1980-07-02
# 4   39846344      Orion Pictures     98.0   1980-07-25

# %%
df=df.sort_values(by=['gross'],inplace=False,ascending=False)

# %%
pd.set_option('display.max_rows', None)

# %%
# Drop any duplicates

df=df.drop_duplicates()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime year_correct
# 5445  2847246203  Twentieth Century Fox    162.0   2009-12-18
# 7445  2797501328         Marvel Studios    181.0   2019-04-26
# 3045  2201647264  Twentieth Century Fox    194.0   1997-12-19
# 6663  2069521700              Lucasfilm    138.0   2015-12-18
# 7244  2048359754         Marvel Studios    149.0   2018-04-27

# %%
# Budget high correlation.
# company high correlation.

# %%
# Scatter plot with budget vs gross


plt.scatter(x=df['budget'],y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Budget for Film')
plt.ylabel('Gross Earnings')
plt.show()

# %%
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime year_correct
# 5445  2847246203  Twentieth Century Fox    162.0   2009-12-18
# 7445  2797501328         Marvel Studios    181.0   2019-04-26
# 3045  2201647264  Twentieth Century Fox    194.0   1997-12-19
# 6663  2069521700              Lucasfilm    138.0   2015-12-18
# 7244  2048359754         Marvel Studios    149.0   2018-04-27

# %%
#Plot budget vs gross using seaborn

sns.regplot(x='budget',y='gross',data=df,scatter_kws={'color':'red'},line_kws={'color':'blue'})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Let's start looking at correlation

# %%
df.corr(method='pearson') #pearson by default ,kendall, spearman
# Out:
#             score     votes    budget     gross   runtime
# score    1.000000  0.409182  0.055665  0.186392  0.399451
# votes    0.409182  1.000000  0.486862  0.632834  0.309212
# budget   0.055665  0.486862  1.000000  0.750157  0.269510
# gross    0.186392  0.632834  0.750157  1.000000  0.245235
# runtime  0.399451  0.309212  0.269510  0.245235  1.000000

# %%
# high correlation between budget and gross

# %%
correlation_matrix=df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
# Looks at company
df.head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country     budget  \
# 5445       James Cameron    Sam Worthington  United States  237000000
# 7445  Christopher Markus  Robert Downey Jr.  United States  356000000
# 3045       James Cameron  Leonardo DiCaprio  United States  200000000
# 6663     Lawrence Kasdan       Daisy Ridley  United States  245000000
# 7244  Christopher Markus  Robert Downey Jr.  United States  321000000
#
#            gross                company  runtime year_correct
# 5445  2847246203  Twentieth Century Fox    162.0   2009-12-18
# 7445  2797501328         Marvel Studios    181.0   2019-04-26
# 3045  2201647264  Twentieth Century Fox    194.0   1997-12-19
# 6663  2069521700              Lucasfilm    138.0   2015-12-18
# 7244  2048359754         Marvel Studios    149.0   2018-04-27

# %%
df_numerized=df

for col_name in df_numerized.columns:
    if (df_numerized[col_name].dtype=='object'):
        df_numerized[col_name]=df_numerized[col_name].astype('category')
        df_numerized[col_name]=df_numerized[col_name].cat.codes

df_numerized.head()
# Out:
#       name  rating  genre  year  released  score      votes  director  writer  \
# 5445   532       5      0    29       696    7.8  1100000.0      1155    1778
# 7445   534       5      0    39       183    8.4   903000.0       162     743
# 3045  6895       5      6    17       704    7.8  1100000.0      1155    1778
# 6663  5143       5      0    35       698    7.8   876000.0      1125    2550
# 7244   535       5      0    38       192    8.4   897000.0       162     743
#
#       star  country     budget       gross  company  runtime year_correct
# 5445  2334       55  237000000  2847246203     2253    162.0   2009-12-18
# 7445  2241       55  356000000  2797501328     1606    181.0   2019-04-26
# 3045  1595       55  200000000  2201647264     2253    194.0   1997-12-19
# 6663   524       55  245000000  2069521700     1540    138.0   2015-12-18
# 7244  2241       55  321000000  2048359754     1606    149.0   2018-04-27

# %%
correlation_matrix=df_numerized.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.title('Correlation Matric for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')
plt.show()

# %%
df_numerized.corr()
# Out:
#               name    rating     genre      year  released     score  \
# name      1.000000 -0.008117  0.016742  0.012278 -0.011491  0.017662
# rating   -0.008117  1.000000  0.072423  0.009280  0.016613 -0.001314
# genre     0.016742  0.072423  1.000000 -0.063573  0.029822  0.027965
# year      0.012278  0.009280 -0.063573  1.000000 -0.010573  0.107219
# released -0.011491  0.016613  0.029822 -0.010573  1.000000  0.042788
# score     0.017662 -0.001314  0.027965  0.107219  0.042788  1.000000
# votes     0.012850  0.033225 -0.145307  0.206475  0.016097  0.409182
# director  0.009754  0.019483 -0.015258 -0.022579 -0.001478  0.009559
# writer    0.009259 -0.005921  0.006567 -0.010063 -0.002404  0.019416
# star      0.007059  0.013405 -0.005477 -0.031166  0.015777 -0.001609
# country  -0.010538  0.081244 -0.037615 -0.090962 -0.020427 -0.133348
# budget    0.020249 -0.081939 -0.334021  0.284783  0.009145  0.055665
# gross     0.006779 -0.095450 -0.234297  0.243478  0.000519  0.186392
# company   0.008356 -0.032943 -0.071067 -0.026492 -0.010474  0.001030
# runtime   0.010118  0.062145 -0.052711  0.115317  0.000868  0.399451
#
#              votes  director    writer      star   country    budget  \
# name      0.012850  0.009754  0.009259  0.007059 -0.010538  0.020249
# rating    0.033225  0.019483 -0.005921  0.013405  0.081244 -0.081939
# genre    -0.145307 -0.015258  0.006567 -0.005477 -0.037615 -0.334021
# year      0.206475 -0.022579 -0.010063 -0.031166 -0.090962  0.284783
# released  0.016097 -0.001478 -0.002404  0.015777 -0.020427  0.009145
# score     0.409182  0.009559  0.019416 -0.001609 -0.133348  0.055665
# votes     1.000000  0.000260  0.000892 -0.019282  0.073625  0.486862
# director  0.000260  1.000000  0.299067  0.039234  0.017490  0.004976
# writer    0.000892  0.299067  1.000000  0.027245  0.015343 -0.025911
# star     -0.019282  0.039234  0.027245  1.000000 -0.012998 -0.019952
# country   0.073625  0.017490  0.015343 -0.012998  1.000000  0.131720
# budget    0.486862  0.004976 -0.025911 -0.019952  0.131720  1.000000
# gross     0.632834 -0.014916 -0.022997 -0.001129  0.095325  0.750157
# company   0.133204  0.004404  0.005646  0.012442  0.095548  0.186474
# runtime   0.309212  0.017624 -0.003511  0.010174 -0.078412  0.269510
#
#              gross   company   runtime
# name      0.006779  0.008356  0.010118
# rating   -0.095450 -0.032943  0.062145
# genre    -0.234297 -0.071067 -0.052711
# year      0.243478 -0.026492  0.115317
# released  0.000519 -0.010474  0.000868
# score     0.186392  0.001030  0.399451
# votes     0.632834  0.133204  0.309212
# director -0.014916  0.004404  0.017624
# writer   -0.022997  0.005646 -0.003511
# star     -0.001129  0.012442  0.010174
# country   0.095325  0.095548 -0.078412
# budget    0.750157  0.186474  0.269510
# gross     1.000000  0.156745  0.245235
# company   0.156745  1.000000  0.034402
# runtime   0.245235  0.034402  1.000000

# %%
correlation_mat =df_numerized.corr()

corr_pairs=correlation_mat.unstack()

corr_pairs
# Out:
# name      name        1.000000
#           rating     -0.008117
#           genre       0.016742
#           year        0.012278
#           released   -0.011491
#           score       0.017662
#           votes       0.012850
#           director    0.009754
#           writer      0.009259
#           star        0.007059
#           country    -0.010538
#           budget      0.020249
#           gross       0.006779
#           company     0.008356
#           runtime     0.010118
# rating    name       -0.008117
#           rating      1.000000
#           genre       0.072423
#           year        0.009280
#           released    0.016613
#           score      -0.001314
#           votes       0.033225
#           director    0.019483
#           writer     -0.005921
#           star        0.013405
#           country     0.081244
#           budget     -0.081939
#           gross      -0.095450
#           company    -0.032943
#           runtime     0.062145
# genre     name        0.016742
#           rating      0.072423
#           genre       1.000000
#           year       -0.063573
#           released    0.029822
#           score       0.027965
#           votes      -0.145307
#           director   -0.015258
#           writer      0.006567
#           star       -0.005477
#           country    -0.037615
#           budget     -0.334021
#           gross      -0.234297
#           company    -0.071067
#           runtime    -0.052711
# year      name        0.012278
#           rating      0.009280
#           genre      -0.063573
#           year        1.000000
#           released   -0.010573
#           score       0.107219
#           votes       0.206475
#           director   -0.022579
#           writer     -0.010063
#           star       -0.031166
#           country    -0.090962
#           budget      0.284783
#           gross       0.243478
#           company    -0.026492
#           runtime     0.115317
# released  name       -0.011491
#           rating      0.016613
#           genre       0.029822
#           year       -0.010573
#           released    1.000000
#           score       0.042788
#           votes       0.016097
#           director   -0.001478
#           writer     -0.002404
#           star        0.015777
#           country    -0.020427
#           budget      0.009145
#           gross       0.000519
#           company    -0.010474
#           runtime     0.000868
# score     name        0.017662
#           rating     -0.001314
#           genre       0.027965
#           year        0.107219
#           released    0.042788
#           score       1.000000
#           votes       0.409182
#           director    0.009559
#           writer      0.019416
#           star       -0.001609
#           country    -0.133348
#           budget      0.055665
#           gross       0.186392
#           company     0.001030
#           runtime     0.399451
# votes     name        0.012850
#           rating      0.033225
#           genre      -0.145307
#           year        0.206475
#           released    0.016097
#           score       0.409182
#           votes       1.000000
#           director    0.000260
#           writer      0.000892
#           star       -0.019282
#           country     0.073625
#           budget      0.486862
#           gross       0.632834
#           company     0.133204
#           runtime     0.309212
# director  name        0.009754
#           rating      0.019483
#           genre      -0.015258
#           year       -0.022579
#           released   -0.001478
#           score       0.009559
#           votes       0.000260
#           director    1.000000
#           writer      0.299067
#           star        0.039234
#           country     0.017490
#           budget      0.004976
#           gross      -0.014916
#           company     0.004404
#           runtime     0.017624
# writer    name        0.009259
#           rating     -0.005921
#           genre       0.006567
#           year       -0.010063
#           released   -0.002404
#           score       0.019416
#           votes       0.000892
#           director    0.299067
#           writer      1.000000
#           star        0.027245
#           country     0.015343
#           budget     -0.025911
#           gross      -0.022997
#           company     0.005646
#           runtime    -0.003511
# star      name        0.007059
#           rating      0.013405
#           genre      -0.005477
#           year       -0.031166
#           released    0.015777
#           score      -0.001609
#           votes      -0.019282
#           director    0.039234
#           writer      0.027245
#           star        1.000000
#           country    -0.012998
#           budget     -0.019952
#           gross      -0.001129
#           company     0.012442
#           runtime     0.010174
# country   name       -0.010538
#           rating      0.081244
#           genre      -0.037615
#           year       -0.090962
#           released   -0.020427
#           score      -0.133348
#           votes       0.073625
#           director    0.017490
#           writer      0.015343
#           star       -0.012998
#           country     1.000000
#           budget      0.131720
#           gross       0.095325
#           company     0.095548
#           runtime    -0.078412
# budget    name        0.020249
#           rating     -0.081939
#           genre      -0.334021
#           year        0.284783
#           released    0.009145
#           score       0.055665
#           votes       0.486862
#           director    0.004976
#           writer     -0.025911
#           star       -0.019952
#           country     0.131720
#           budget      1.000000
#           gross       0.750157
#           company     0.186474
#           runtime     0.269510
# gross     name        0.006779
#           rating     -0.095450
#           genre      -0.234297
#           year        0.243478
#           released    0.000519
#           score       0.186392
#           votes       0.632834
#           director   -0.014916
#           writer     -0.022997
#           star       -0.001129
#           country     0.095325
#           budget      0.750157
#           gross       1.000000
#           company     0.156745
#           runtime     0.245235
# company   name        0.008356
#           rating     -0.032943
#           genre      -0.071067
#           year       -0.026492
#           released   -0.010474
#           score       0.001030
#           votes       0.133204
#           director    0.004404
#           writer      0.005646
#           star        0.012442
#           country     0.095548
#           budget      0.186474
#           gross       0.156745
#           company     1.000000
#           runtime     0.034402
# runtime   name        0.010118
#           rating      0.062145
#           genre      -0.052711
#           year        0.115317
#           released    0.000868
#           score       0.399451
#           votes       0.309212
#           director    0.017624
#           writer     -0.003511
#           star        0.010174
#           country    -0.078412
#           budget      0.269510
#           gross       0.245235
#           company     0.034402
#           runtime     1.000000
# dtype: float64

# %%
sorted_pairs=corr_pairs.sort_values()
sorted_pairs
# Out:
# budget    genre      -0.334021
# genre     budget     -0.334021
# gross     genre      -0.234297
# genre     gross      -0.234297
#           votes      -0.145307
# votes     genre      -0.145307
# country   score      -0.133348
# score     country    -0.133348
# rating    gross      -0.095450
# gross     rating     -0.095450
# country   year       -0.090962
# year      country    -0.090962
# rating    budget     -0.081939
# budget    rating     -0.081939
# country   runtime    -0.078412
# runtime   country    -0.078412
# company   genre      -0.071067
# genre     company    -0.071067
#           year       -0.063573
# year      genre      -0.063573
# runtime   genre      -0.052711
# genre     runtime    -0.052711
#           country    -0.037615
# country   genre      -0.037615
# rating    company    -0.032943
# company   rating     -0.032943
# star      year       -0.031166
# year      star       -0.031166
# company   year       -0.026492
# year      company    -0.026492
# budget    writer     -0.025911
# writer    budget     -0.025911
# gross     writer     -0.022997
# writer    gross      -0.022997
# director  year       -0.022579
# year      director   -0.022579
# released  country    -0.020427
# country   released   -0.020427
# budget    star       -0.019952
# star      budget     -0.019952
# votes     star       -0.019282
# star      votes      -0.019282
# director  genre      -0.015258
# genre     director   -0.015258
# director  gross      -0.014916
# gross     director   -0.014916
# star      country    -0.012998
# country   star       -0.012998
# released  name       -0.011491
# name      released   -0.011491
# year      released   -0.010573
# released  year       -0.010573
# name      country    -0.010538
# country   name       -0.010538
# released  company    -0.010474
# company   released   -0.010474
# writer    year       -0.010063
# year      writer     -0.010063
# rating    name       -0.008117
# name      rating     -0.008117
# rating    writer     -0.005921
# writer    rating     -0.005921
# genre     star       -0.005477
# star      genre      -0.005477
# runtime   writer     -0.003511
# writer    runtime    -0.003511
# released  writer     -0.002404
# writer    released   -0.002404
# score     star       -0.001609
# star      score      -0.001609
# director  released   -0.001478
# released  director   -0.001478
# rating    score      -0.001314
# score     rating     -0.001314
# star      gross      -0.001129
# gross     star       -0.001129
# votes     director    0.000260
# director  votes       0.000260
# released  gross       0.000519
# gross     released    0.000519
# released  runtime     0.000868
# runtime   released    0.000868
# writer    votes       0.000892
# votes     writer      0.000892
# score     company     0.001030
# company   score       0.001030
#           director    0.004404
# director  company     0.004404
# budget    director    0.004976
# director  budget      0.004976
# writer    company     0.005646
# company   writer      0.005646
# genre     writer      0.006567
# writer    genre       0.006567
# gross     name        0.006779
# name      gross       0.006779
# star      name        0.007059
# name      star        0.007059
#           company     0.008356
# company   name        0.008356
# released  budget      0.009145
# budget    released    0.009145
# writer    name        0.009259
# name      writer      0.009259
# rating    year        0.009280
# year      rating      0.009280
# score     director    0.009559
# director  score       0.009559
# name      director    0.009754
# director  name        0.009754
# runtime   name        0.010118
# name      runtime     0.010118
# star      runtime     0.010174
# runtime   star        0.010174
# year      name        0.012278
# name      year        0.012278
# star      company     0.012442
# company   star        0.012442
# name      votes       0.012850
# votes     name        0.012850
# star      rating      0.013405
# rating    star        0.013405
# writer    country     0.015343
# country   writer      0.015343
# star      released    0.015777
# released  star        0.015777
# votes     released    0.016097
# released  votes       0.016097
# rating    released    0.016613
# released  rating      0.016613
# genre     name        0.016742
# name      genre       0.016742
# director  country     0.017490
# country   director    0.017490
# runtime   director    0.017624
# director  runtime     0.017624
# name      score       0.017662
# score     name        0.017662
#           writer      0.019416
# writer    score       0.019416
# rating    director    0.019483
# director  rating      0.019483
# budget    name        0.020249
# name      budget      0.020249
# writer    star        0.027245
# star      writer      0.027245
# genre     score       0.027965
# score     genre       0.027965
# genre     released    0.029822
# released  genre       0.029822
# rating    votes       0.033225
# votes     rating      0.033225
# company   runtime     0.034402
# runtime   company     0.034402
# star      director    0.039234
# director  star        0.039234
# score     released    0.042788
# released  score       0.042788
# score     budget      0.055665
# budget    score       0.055665
# runtime   rating      0.062145
# rating    runtime     0.062145
# genre     rating      0.072423
# rating    genre       0.072423
# country   votes       0.073625
# votes     country     0.073625
# rating    country     0.081244
# country   rating      0.081244
#           gross       0.095325
# gross     country     0.095325
# company   country     0.095548
# country   company     0.095548
# score     year        0.107219
# year      score       0.107219
#           runtime     0.115317
# runtime   year        0.115317
# budget    country     0.131720
# country   budget      0.131720
# votes     company     0.133204
# company   votes       0.133204
#           gross       0.156745
# gross     company     0.156745
#           score       0.186392
# score     gross       0.186392
# budget    company     0.186474
# company   budget      0.186474
# votes     year        0.206475
# year      votes       0.206475
#           gross       0.243478
# gross     year        0.243478
#           runtime     0.245235
# runtime   gross       0.245235
# budget    runtime     0.269510
# runtime   budget      0.269510
# budget    year        0.284783
# year      budget      0.284783
# director  writer      0.299067
# writer    director    0.299067
# votes     runtime     0.309212
# runtime   votes       0.309212
# score     runtime     0.399451
# runtime   score       0.399451
# votes     score       0.409182
# score     votes       0.409182
# budget    votes       0.486862
# votes     budget      0.486862
# gross     votes       0.632834
# votes     gross       0.632834
# budget    gross       0.750157
# gross     budget      0.750157
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
high_corr=sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# gross     votes       0.632834
# votes     gross       0.632834
# budget    gross       0.750157
# gross     budget      0.750157
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# Votes and budget have the highest correlation to gross earning.
#Company has low corelation
